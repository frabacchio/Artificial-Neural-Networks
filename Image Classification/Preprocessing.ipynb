# %%
import json
import os
from google.colab import drive
import shutil
import glob
import random
from PIL import Image

# %%
cwd='/content/drive/My Drive'

images = json.load(open('/content/drive/My Drive/MaskDataset/train_gt.json'))
for x,y in images.items():
  c="/content/drive/My Drive/MaskDataset/training/"+x
  if(y==0):
   shutil.move(c,"/content/drive/My Drive/MaskDataset/0") 
  if(y==1):
   shutil.move(c,"/content/drive/My Drive/MaskDataset/1")
  if(y==2):
   shutil.move(c,"/content/drive/My Drive/MaskDataset/2")
